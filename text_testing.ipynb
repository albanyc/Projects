# %% [markdown]
# <a href="https://colab.research.google.com/github/albanyc/Projects/blob/master/text_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# !python --version
# import pandas as pd
# pd.__version__
# import numpy as np
# np.__version__

# %%
# !python --version
import pandas as pd
pd.__version__
import numpy as np
np.__version__
# Out:
# Python 3.7.13
# '1.21.6'

# %%
url='https://raw.githubusercontent.com/LilianaC/Pandas/master/FIFA21_official_data.csv'
df=pd.read_csv(url)

# %%
df[df['Club'].strcontains('Madrid')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0ec08cc64083> in <module>()
# ----> 1 df[df['Club'].strcontains('Madrid')]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strcontains'

# %%
df=df.fillna('')

# %%
df.shape
# Out:
# (17108, 65)

# %%
df.isna().sum().sum()
# Out:
# 37849

# %%
df[df['Club'].str.contains('Madrid')]
# Out:
#            ID              Name  Age  \
# 0      176580         L. Suárez   33
# 11     155862      Sergio Ramos   34
# 13     177003         L. Modrić   34
# 23     200145          Casemiro   28
# 27     208421              Saúl   25
# ...       ...               ...  ...
# 16181  243952          A. Lunin   21
# 16714  243308   Álex Dos Santos   21
# 16746  242802         San Román   22
# 16773  258390          I. Grbić   24
# 16781  247411            Altube   20
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 11     https://cdn.sofifa.com/players/155/862/20_60.png       Spain
# 13     https://cdn.sofifa.com/players/177/003/20_60.png     Croatia
# 23     https://cdn.sofifa.com/players/200/145/20_60.png      Brazil
# 27     https://cdn.sofifa.com/players/208/421/20_60.png       Spain
# ...                                                 ...         ...
# ...

# %%
df[df['Club'].str.contains('Madrid',na=False)]
# Out:
#            ID              Name  Age  \
# 0      176580         L. Suárez   33
# 11     155862      Sergio Ramos   34
# 13     177003         L. Modrić   34
# 23     200145          Casemiro   28
# 27     208421              Saúl   25
# ...       ...               ...  ...
# 16181  243952          A. Lunin   21
# 16714  243308   Álex Dos Santos   21
# 16746  242802         San Román   22
# 16773  258390          I. Grbić   24
# 16781  247411            Altube   20
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 11     https://cdn.sofifa.com/players/155/862/20_60.png       Spain
# 13     https://cdn.sofifa.com/players/177/003/20_60.png     Croatia
# 23     https://cdn.sofifa.com/players/200/145/20_60.png      Brazil
# 27     https://cdn.sofifa.com/players/208/421/20_60.png       Spain
# ...                                                 ...         ...
# ...

# %%
df['Hay']=df['Club'].str.contains('Madrid')

# %%
df['Hay'].value_counts()
# Out:
# False    16710
# True        73
# Name: Hay, dtype: int64

# %%
df['Club'].str.contains('Madrid',case=False)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17103    False
# 17104    False
# 17105    False
# 17106    False
# 17107    False
# Name: Club, Length: 17108, dtype: object

# %%
test=df[df['Club'].str.contains('madrid|barcelona',case=False,na=False,regex=True)] #regex activado en True permite buscar madrid or barcelona

# %%
test
# Out:
#            ID              Name  Age  \
# 0      176580         L. Suárez   33
# 3      194765      A. Griezmann   29
# 11     155862      Sergio Ramos   34
# 13     177003         L. Modrić   34
# 18     158023          L. Messi   33
# ...       ...               ...  ...
# 16606  246139        Iñaki Peña   21
# 16714  243308   Álex Dos Santos   21
# 16746  242802         San Román   22
# 16773  258390          I. Grbić   24
# 16781  247411            Altube   20
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/194/765/20_60.png      France
# 11     https://cdn.sofifa.com/players/155/862/20_60.png       Spain
# 13     https://cdn.sofifa.com/players/177/003/20_60.png     Croatia
# 18     https://cdn.sofifa.com/players/158/023/20_60.png   Argentina
# ...                                                 ...         ...
# ...

# %%
df = pd.DataFrame({'num_legs': ['cannot reset password', 'sso'], 'num_wings': [2, 0]},
                  index=['falcon', 'dog'])
df
# Out:
#                      num_legs  num_wings
# falcon  cannot reset password          2
# dog                       sso          0

# %%
values=['passw', 'sso']
dsa_str='|'.join(values)
df.stack().str.contains(dsa_str)
# Out:
# falcon  num_legs     True
#         num_wings     NaN
# dog     num_legs     True
#         num_wings     NaN
# dtype: object

# %%
df['num_legs'] in values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-26fe756b4061> in <module>()
# ----> 1 df['num_legs'] in values
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
